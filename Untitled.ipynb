# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('IceCreamData.csv')
df
# Out:
#      Temperature     Revenue
# 0      24.566884  534.799028
# 1      26.005191  625.190122
# 2      27.790554  660.632289
# 3      20.595335  487.706960
# 4      11.503498  316.240194
# ..           ...         ...
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388
#
# [500 rows x 2 columns]

# %%
celsius = (df['Temperature'] - 32) *  5/9
df['Temperature'] = celsius
df
# Out:
#      Temperature     Revenue
# 0     -20.071949  534.799028
# 1     -19.628027  625.190122
# 2     -19.076990  660.632289
# 3     -21.297736  487.706960
# 4     -24.103859  316.240194
# ..           ...         ...
# 495   -20.779352  524.746364
# 496   -17.502132  755.818399
# 497   -23.769087  306.090719
# 498   -20.752345  566.217304
# 499   -18.716748  655.660388
#
# [500 rows x 2 columns]

# %%
result = df.sort_values('Temperature', ascending = False)
result
# Out:
#      Temperature      Revenue
# 444   -13.765432  1000.000000
# 17    -14.532321   921.508275
# 329   -14.714677   965.493040
# 413   -14.763398   969.291630
# 76    -15.162349   918.391232
# ..           ...          ...
# 63    -26.423913   131.657017
# 11    -26.523250    71.160153
# 8     -27.352818    55.390338
# 371   -27.571905    32.546619
# 402   -27.654321    10.000000
#
# [500 rows x 2 columns]

# %%
plt.plot(result['Temperature'], result['Revenue'], 'r.--', label = 'US$')
plt.title('Ice Cream Truck')
plt.ylabel('Sales (US$)')
plt.xlabel('Temperature (celsius)')
plt.legend()
plt.savefig('icecream_sales3.pdf')
plt.show()
